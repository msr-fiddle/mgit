# %%
import sys
MGIT_PATH=os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
sys.path.append(MGIT_PATH)
from utils.lineage.graph import *
import re

# %% [markdown]
# # Table.4 Accuracy Delta

# %%
t1 = '+----------------------------------------------------------------------------------+-------+-------+----------+----------+ | nodes/tests                                                                      | mlm   | mnli  | squad_v1 | squad_v2 | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/bert-base-cased                                               | 2.295 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/bert-base-uncased                                             | 2.413 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/aloxatel/bert-base-mnli                                       |       | 0.847 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/ericRosello/bert-base-uncased-finetuned-squad-frozen-v2       |       |       | 85.419   | 42.809   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/deepset/bert-base-uncased-squad2                              |       |       | 90.516   | 78.403   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/bert-large-uncased                                            | 2.312 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/bert-large-cased                                              | 2.337 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/TehranNLP-org/bert-large-mnli                                 |       | 0.080 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/roberta-base                                                  | 2.482 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/deepset/roberta-base-squad2                                   |       |       | 91.816   | 82.917   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/textattack/roberta-base-MNLI                                  |       | 0.348 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/roberta-large                                                 | 2.610 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/roberta-large-mnli                                            |       | 0.355 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/deepset/roberta-large-squad2                                  |       |       | 93.662   | 88.277   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/albert-base-v2                                                | 8.826 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/twmkn9/albert-base-v2-squad2                                  |       |       | 89.462   | 81.211   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/prajjwal1/albert-base-v2-mnli                                 |       | 0.849 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/distilbert-base-uncased                                       | 2.622 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/distilbert-base-cased                                         | 3.144 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/twmkn9/distilbert-base-uncased-squad2                         |       |       | 85.578   | 69.763   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/ericRosello/distilbert-base-uncased-finetuned-squad-frozen-v2 |       |       | 82.718   | 41.218   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/google/electra-small-generator                                | 6.025 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/howey/electra-small-mnli                                      |       | 0.102 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+'
t2 = '+----------------------------------------------------------------------------------+-------+-------+----------+----------+ | nodes/tests                                                                      | mlm   | mnli  | squad_v1 | squad_v2 | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/bert-base-cased                                               | 2.295 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/bert-base-uncased                                             | 2.413 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/aloxatel/bert-base-mnli                                       |       | 0.847 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/ericRosello/bert-base-uncased-finetuned-squad-frozen-v2       |       |       | 85.419   | 42.809   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/deepset/bert-base-uncased-squad2                              |       |       | 90.516   | 78.403   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/bert-large-uncased                                            | 2.312 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/bert-large-cased                                              | 2.337 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/TehranNLP-org/bert-large-mnli                                 |       | 0.080 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/roberta-base                                                  | 2.482 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/deepset/roberta-base-squad2                                   |       |       | 91.816   | 82.917   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/textattack/roberta-base-MNLI                                  |       | 0.348 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/roberta-large                                                 | 2.610 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/roberta-large-mnli                                            |       | 0.355 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/deepset/roberta-large-squad2                                  |       |       | 93.662   | 88.277   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/albert-base-v2                                                | 8.826 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/twmkn9/albert-base-v2-squad2                                  |       |       | 89.462   | 81.211   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/prajjwal1/albert-base-v2-mnli                                 |       | 0.849 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/distilbert-base-uncased                                       | 2.622 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/distilbert-base-cased                                         | 3.144 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/twmkn9/distilbert-base-uncased-squad2                         |       |       | 85.578   | 69.763   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/ericRosello/distilbert-base-uncased-finetuned-squad-frozen-v2 |       |       | 82.718   | 41.218   | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/google/electra-small-generator                                | 6.025 |       |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+ | ../../../models/g1/howey/electra-small-mnli                                      |       | 0.102 |          |          | +----------------------------------------------------------------------------------+-------+-------+----------+----------+'

# %%
# Replace '| -     |' with '| 0   |'
table1 = re.sub(r' - ', ' 0.0 ', t1)
table2 = re.sub(r' - ', ' 0.0 ', t2)

# Parse fractions between '|' and '|'
fractions1 = re.findall(r'\d+\.\d+', table1)
fractions2 = re.findall(r'\d+\.\d+', table2)

# Convert fractions to floats
fractions1 = [float(f) for f in fractions1]
fractions2 = [float(f) for f in fractions2]
fractions2 = [fractions1[i] if fractions2[i] == 0 else fractions2[i] for i in range(len(fractions2)) ]

print(len(fractions1))
print(len(fractions2))
# Out:
# 30
# 30

# %%
c = [ fractions1[i] - fractions2[i] for i in range(len(fractions1))]
c = [c[i] if c[i] > 0 else 0 for i in range(len(c))]
#c = [c[i] for i in range(len(c))if (i+1)%2 == 0]
print(max(c), sum(c)/len(c))
# Out:
# 0 0.0

# %% [markdown]
# # Graph Visualization from JSON

# %%
g = LineageGraph.load_from_file('./',filename='g5.json')
graph = g.show(save_path="./g5.html")

# %% [markdown]
# # Download HGF Model Snapshot

# %%
import huggingface_hub as hf
from huggingface_hub import snapshot_download
#hf.model_info("bert-base-uncased")
model = snapshot_download("bert-base-uncased",ignore_regex=['*.safetensors*','*tokenizer*','*.rust_model.ot*','*.msgpack*','*.pt*','*.bin*','*.h5*'])
hf.model_info("bert-base-uncased", files_metadata=True).siblings
